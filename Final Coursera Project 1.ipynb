# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Taylor Peacock
# Data Analyst and Business Owner

# %% [markdown]
# *I am interested in data science because it's a field of study where nothing is the same. You work with different data all the time. I'm so fascinated with the technical aspect of it such as programming and analyzing. Plus, I'd be a good fit because I'm amazing at problem solving.*

# %% [markdown]
# ### The following code is an input of someone's age with an output of whether they can buy alcohol or not.

# %%
print("Can you buy alcohol?")

age = 24

if age >= 21:
    print("Yes")
# Out:
# Can you buy alcohol?
# Yes

# %% [markdown]
# While you're here, check out my [Etsy Shop](https://www.etsy.com/shop/TaylorsUniqueCandles?ref=shop_sugg_market)
#
# My shop includes:
# 1. Wax Melts
# 2. Candles
#
# I only have three products up so far:
#
# | Type     | Color   |
# | :------- | :------ |
# | wax melt | any     |
# | wax melt | rainbow |
# | candle   | any     |
